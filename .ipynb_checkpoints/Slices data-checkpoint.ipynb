# %%
import numpy as np
import h5py as hp
import seaborn as sbs
from matplotlib import pyplot as plt
from postprocessing_funcs import *
from matplotlib import animation, rc
from IPython.display import HTML

# %%
sbs.set(rc={'figure.figsize':(8.3, 5.2)}, style='white', palette='colorblind', context='notebook')

# %%
folder = '/home/vgubaidulin/PhD/Data_server/Stability_scans/HLLHC/sc/'
real = 0.
imag = 0.
mean_x, mean_z = get_slice_data(real, imag, folder)

# %%
def plot_turn(i, ax):
    ax.plot(mean_z[:,i], mean_x[:, i], color='black', alpha=0.4)
fig, ax = plt.subplots(1, 1)
for turn in range(0, 4000):
    plot_turn(turn, ax)
plt.show()

# %%
# %%time
fig, ax = plt.subplots()
x = mean_x[:, -1000:]
line, = ax.plot([], [], color='black')
# initialization function: plot the background of each frame
def init():
    plt.xlabel('$z$ [m]', fontsize=18)
    line.set_data([], [])
    plt.xlim(0, x[:, 0].shape[0])
    plt.ylim(min(np.mean(mean_x, axis=0)), max(np.mean(mean_x), axis=0))
    return (line,)
def animate(i):
    line.set_data(range(x[:, i].shape[0]), x[:, i])
    plt.legend((r'Turn={:4d}'.format(i),))
    return (line, )
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=int(x[0, :].shape[0]), interval=250, blit=True)
HTML(anim.to_html5_video())
# Out:
# Traceback (most recent call last):
#
#   File "/home/vgubaidulin/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-11-241aefc9ef3f>", line 1, in <module>
#     get_ipython().run_cell_magic('time', '', "fig, ax = plt.subplots()\nx = mean_x[:, -1000:]\nline, = ax.plot([], [], color='black')\n# initialization function: plot the background of each frame\ndef init():\n    plt.xlabel('$z$ [m]', fontsize=18)\n    line.set_data([], [])\n    plt.xlim(0, x[:, 0].shape[0])\n    plt.ylim(min(np.mean(mean_x, axis=0)), max(np.mean(mean)x, axis=0))\n    return (line,)\ndef animate(i):\n    line.set_data(range(x[:, i].shape[0]), x[:, i])\n    plt.legend((r'Turn={:4d}'.format(i),))\n    return (line, )\nanim = animation.FuncAnimation(fig, animate, init_func=init,\n                               frames=int(x[0, :].shape[0]), interval=250, blit=True)\nHTML(anim.to_html5_video())\n")
#
#   File "/home/vgubaidulin/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2359, in run_cell_magic
#     result = fn(*args, **kwargs)
#
#   File "</home/vgubaidulin/anaconda3/lib/python3.7/site-packages/decorator.py:decorator-gen-61>", line 2, in time
#
#   File "/home/vgubaidulin/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#
#   File "/home/vgubaidulin/anaconda3/lib/python3.7/site-packages/IPython/core/magics/execution.py", line 1266, in time
#     expr_ast = self.shell.compile.ast_parse(expr)
#
#   File "/home/vgubaidulin/anaconda3/lib/python3.7/site-packages/IPython/core/compilerop.py", line 101, in ast_parse
#     return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#
#   File "<unknown>", line 9
#     plt.ylim(min(np.mean(mean_x, axis=0)), max(np.mean(mean)x, axis=0))
#                                                             ^
# SyntaxError: invalid syntax
